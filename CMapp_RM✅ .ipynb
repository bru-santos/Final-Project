# %% [markdown]
#  ### 🍎🫐🥝🥗🥘🍎🫐🥝🥗🥘 CLEVER MEAL  B2B🍎🫐🥝🥗🥘🍎🫐🥝🥗🥘

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (1.25.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: validators<1,>=0.2 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (13.4.2)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (22.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: pydeck<1,>=0.8 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: pillow<10,>=7.1.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: requests<3,>=2.18 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (2.29.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (3.1.32)
# Requirement already satisfied: altair<6,>=4.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (4.23.4)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (6.1)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: pyarrow>=6.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (12.0.1)
# Requirement already satisfied: pympler<2,>=0.9 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: tzlocal<5,>=1.1 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (4.3.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: jinja2 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: toolz in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.18->streamlit) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from tzlocal<5,>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: tzdata in /Users/brunasantos/anaconda3/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit) (2023.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import streamlit as st

from sklearn import datasets # sklearn comes with some toy datasets to practice
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
from PIL import Image
from IPython.display import display

get_ipython().run_line_magic('matplotlib', 'inline')

# %%
df= pd.read_csv("all_recipes_FV.csv")

# %%
df
# Out:
#      Diet_type                                        Recipe_name  \
# 0        paleo                    Bone Broth From 'Nom Nom Paleo'
# 1        paleo  Paleo Effect Asian-Glazed Pork Sides, A Sweet ...
# 2        paleo                                  Paleo Pumpkin Pie
# 3        paleo                       Strawberry Guacamole recipes
# 4        paleo  Asian Cauliflower Fried "Rice" From 'Nom Nom P...
# ...        ...                                                ...
# 7801      dash  Brown Butter-Sunchoke Soup With Brussels Sprou...
# 7802      dash                                Make-Your-Own-Salad
# 7803      dash                            Luis Buñuel Dry Martini
# 7804      dash               Cornflake Semi-Fried Chicken Tenders
# 7805      dash                         Emeril's Classic Manhattan
#
#           Cuisine_type  Protein(g)  Carbs(g)  Fat(g)  Protein Calorie  \
# 0             american        5.22      1.29    3.20            20.88
# 1     south east asian      181.55     28.62  146.14           726.20
# 2             american       30.91    302.59   96.76           123.64
# 3              mexican        9.62     75.78   59.89            38.48
# 4              chinese       39.84     54.08   71.55           159.36
# ...                ...         ...       ...     ...              ...
# 7801           italian       85.20    288.14  137.15           340.80
# 7802          american      141.98    123.18  323.50           567.92
# 7803             world        0.01      0.39    0.00             0.04
# 7804          american      155.38    239.88  260.84           621.52
# 7805          american        0.02      0.83    0.00             0.08
#
#       Carbs Calorie  Fat Calorie  Total Calories
# 0              5.16        12.80           38.84
# 1            114.48       584.56         1425.24
# 2           1210.36       387.04         1721.04
# 3            303.12       239.56          581.16
# 4            216.32       286.20          661.88
# ...             ...          ...             ...
# 7801        1152.56       548.60         2041.96
# 7802         492.72      1294.00         2354.64
# 7803           1.56         0.00            1.60
# 7804         959.52      1043.36         2624.40
# 7805           3.32         0.00            3.40
#
# [7806 rows x 10 columns]

# %%
X = df[["Protein(g)","Protein Calorie","Carbs(g)","Carbs Calorie", "Fat(g)", "Fat Calorie", "Total Calories"]]


# Scalling
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)  # we are getting an array


# we need to get our dataframe
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)


# KMeans 01
kmeans = KMeans(n_clusters=10, random_state=1234)
kmeans.fit(X_scaled_df)

kmeans.inertia_


# KMeans Lebels
labels = kmeans.labels_

#Clusters
clusters = kmeans.predict(X_scaled_df)

# Adding Cluster in X
X["cluster"] = clusters

# Final Data Frame
df_final = pd.merge(X, df[['Recipe_name', "Cuisine_type","Diet_type"]], left_index=True, right_index=True)
# Out:
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /var/folders/0h/qsc9xv295z7clcdd_1p3h2w00000gn/T/ipykernel_45437/3868380958.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["cluster"] = clusters

# %% [markdown]
# ### K Means Training Function

# %%
def treining_KMeans_Model(input_file):
    
    df = pd.read_csv(input_file)
    
    # Splintg variables
    X = df[["Protein(g)","Protein Calorie","Carbs(g)","Carbs Calorie", "Fat(g)", "Fat Calorie", "Total Calories"]]
    
    # Scalling
    scaler = StandardScaler()
    scaler.fit(X)
    X_scaled = scaler.transform(X)  # we are getting an array
    
    # we need to get our dataframe
    X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)


    # KMeans 01
    kmeans = KMeans(n_clusters=10, random_state=1234)
    kmeans.fit(X_scaled_df)

    kmeans.inertia_


    # KMeans Lebels
    labels = kmeans.labels_

    #Clusters
    clusters = kmeans.predict(X_scaled_df)

    # Adding Cluster in X
    X["cluster"] = clusters

    # Final Data Frame
    df_final = pd.merge(X, df[['Recipe_name', "Cuisine_type","Diet_type"]], left_index=True, right_index=True)
    
    return df_final

# %% [markdown]
# ## User Inputs

# %% [markdown]
# ## Total Calories per  MEAL🥗✅

# %%
def get_non_empty_float(prompt):
    while True:
        try:
            value = float(input(prompt))
            if value <= 0:
                print("Please enter a positive non-zero value.")
            else:
                return value
        except ValueError:
            print("Invalid input. Please enter a valid number.")

# %%
def get_gender():
    while True:
        gender = input("Gender (male/female): ").lower()
        if gender in ['male', 'female']:
            return gender
        else:
            print("Invalid gender. Please enter 'male' or 'female'.")

# %%
def get_activity_level():
    
    # Define a list of correct spellings or keywords:
    # correct_spellings = ["sedentary", "lightly active", "moderately active", "very active"]

    activity_levels = ['sedentary', 'lightly active', 'moderately active', 'very active', 'extra active']
    

    
    
    while True:
        nivel_activity = input("Activity Level (sedentary/lightly active/moderately active/very active/extra active): ").lower()
        
        # closest match
        #closest_match, similarity_score = process.extractOne(nivel_activity, activity_levels)
        
        if nivel_activity in activity_levels:
            return nivel_activity
        else:
            print("Invalid activity level. Please choose from the provided options.")

# %%
def get_user_goal():
    
    # Define a list of correct spellings or keywords:
    user_goal = ['loss weight', 'maintain weight', 'gain weight']
    
    while True:
        user_goals_input = input("What is your Goal: (Loss Weight/Maintain Weight/Gain Weight: ").lower()
        
        # closest match
        #closest_match, similarity_score = process.extractOne(nivel_activity, activity_levels)
        
        if user_goals_input in user_goal:
            return user_goals_input
        else:
            print("Invalid user goal. Please choose from the provided options.")

# %%
def calculate_bmr(weight, height, age, gender):
    # BMR calculation using the Harris-Benedict equation
    if gender == "male":
        bmr = 88.362 + (13.397 * weight) + (4.799 * height) - (5.677 * age)
    else:
        bmr = 447.593 + (9.247 * weight) + (3.098 * height) - (4.330 * age)
    return bmr

# %% [markdown]
# ## 🍎🫐🥝🥗🥘🍎🫐🥝🥗🍎🫐🥝🥗🥘🍎🫐🥝🥗🍎🫐🥝🥗🥘🍎🫐🥝🥗

# %%
def calculate_macronutrient_distribution(TDEE):
    
    # List to store user inputs
    user_data = []  
    
    # Macronutrient Ratios
    protein_ratio = 0.3
    fat_ratio = 0.3
    carbohydrate_ratio = 0.4

    # Caloric content per gram of each macronutrient
    protein_calories_per_gram = 4
    fat_calories_per_gram = 9
    carbohydrate_calories_per_gram = 4

    # Calculate the grams of each macronutrient
    protein_grams = (protein_ratio * TDEE) / protein_calories_per_gram
    fat_grams = (fat_ratio * TDEE) / fat_calories_per_gram
    carbohydrate_grams = (carbohydrate_ratio * TDEE) / carbohydrate_calories_per_gram

    # Calculate the calories contributed by each macronutrient
    protein_calories = protein_grams * protein_calories_per_gram
    fat_calories = fat_grams * fat_calories_per_gram
    carbohydrate_calories = carbohydrate_grams * carbohydrate_calories_per_gram
    
    #Total Calories
    total_calories = carbohydrate_calories + fat_calories + protein_calories
    
    user_data.append(
            {
        "Protein(g)": protein_grams,
        "Protein Calorie": protein_calories,
        "Carbs(g)": carbohydrate_grams,
        "Carbs Calorie": carbohydrate_calories,
        "Fat(g)": fat_grams,
        "Fat Calorie": fat_calories,
        "Total Calories": total_calories
    })
        
    user_inputs_df = pd.DataFrame(user_data)
    

    return {
        "Protein(g)": protein_grams,
        "Protein Calorie": protein_calories,
        "Carbs(g)": carbohydrate_grams,
        "Carbs Calorie": carbohydrate_calories,
        "Fat(g)": fat_grams,
        "Fat Calorie": fat_calories,
        "Total Calories": total_calories
    }

def TDEE_calculator_per_meal():
    print("Welcome to the TDEE Calculator!")
    print("Please enter the following details:")

    weight = get_non_empty_float("Weight (kg): ")
    height = get_non_empty_float("Height (cm): ")
    age = get_non_empty_float("Age (years): ")
    gender = get_gender()
    nivel_activity = get_activity_level()
    user_goals = get_user_goal()

    # Basal Metabolic Rate (BMR)
    bmr = calculate_bmr(weight, height, age, gender)

    activity_factors = {
        "sedentary": 1.2,
        "lightly active": 1.375,
        "moderately active": 1.55,
        "very active": 1.725,
        "extra active": 1.9
    }
    
    TDEE_goals = {
        "loss weight": 0.85,
        "maintain weight": 1,
        "gain weight": 1.1
    }

        ##### PER MEAL

    # Create a list to hold the data for the DataFrame
    user_inputs_parameters = []

    # Set a default value for TDEE
    TDEE = None

    if nivel_activity in activity_factors:
        TDEE = (bmr * activity_factors[nivel_activity]) / 3

    if user_goals in TDEE_goals:
        TDEE *= TDEE_goals[user_goals]
        print(f"Total Calories per meal based on your Goal is: {TDEE:.2f} calories per meal.")
    else:
        print("Invalid goal. Please choose from the provided options.")
    #else:
    #print("Invalid activity level. Please choose from the provided options.")
         
        
    # Calculate and display the macronutrient distribution
    macronutrient_distribution = calculate_macronutrient_distribution(TDEE)
        
    print("\nMacronutrient Distribution:")
        
    for macronutrients, value in macronutrient_distribution.items():   
    
            
    # Append the nutrient and value to the data list as a tuple
         user_inputs_parameters.append((macronutrients, value))
            
    # Create a DataFrame from the data list
         df_user_inputs = pd.DataFrame(user_inputs_parameters, columns=["Macronutrients", "Value"])
            
    else:
        print("Invalid activity level. Please choose from the provided options.")
        
    # Transpose the DataFrame
    df_user_inputs_TP = df_user_inputs.transpose()


    # Changing the columns names

    custom_column_names = {
                  "0": "Protein(g)",
                  "1": "Protein Calorie",
                  "2": "Carbs(g)",
                  "3": "Carbs Calorie",
                  "4": "Fat(g)",
                  "5": "Fat Calorie",
                  "6": "Total Calories"}

    df_user_inputs_TP.columns = custom_column_names.values()


    # Dropping the columns "Macronutrients"

    df_user_inputs_TP = df_user_inputs_TP.drop(index="Macronutrients")

    # Resetting the index
    df_user_inputs_TP = df_user_inputs_TP.reset_index(drop=True)
        
    return df_user_inputs_TP

# %% [markdown]
# ## 🍎🫐🥝🥗🥘🍎🫐🥝🥗🍎🫐🥝🥗🥘🍎🫐🥝🥗

# %%
def recipe_recommendation():
    
    
    df_user_inputs_parameter = TDEE_calculator_per_meal()


    # Scaling the user inputs DataFrame

    scaler = StandardScaler()

    scaler.fit(df_user_inputs_parameter)
    scaler.transform(df_user_inputs_parameter)
    user_inputs_scaled = scaler.transform(df_user_inputs_parameter)

    # Apply KMeans prediction to user_inputs_scaled
    user_cluster = kmeans.predict(user_inputs_scaled)

    # Filter recommended recipe based on predicted cluster

    recommended_recipe_from_cluster = df_final[df_final['cluster'] == user_cluster[0]]

    # Select a random recipe from recommended recipes
    recommended_recipe = recommended_recipe_from_cluster.sample(n=1)
    
    return recommended_recipe

# %%
recipe_recommendation()
# Out:
# Welcome to the TDEE Calculator!
# Please enter the following details:
# Weight (kg): 55
# Height (cm): 158
# Age (years): 36
# Gender (male/female): female
# Activity Level (sedentary/lightly active/moderately active/very active/extra active): very active
# What is your Goal: (Loss Weight/Maintain Weight/Gain Weight: loss weight
# Total Calories per meal based on your Goal is: 630.38 calories per meal.
#
# Macronutrient Distribution:
# Invalid activity level. Please choose from the provided options.
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
#       Protein(g)  Protein Calorie  Carbs(g)  Carbs Calorie  Fat(g)  \
# 3671       83.53           334.12    111.03         444.12  132.41
#
#       Fat Calorie  Total Calories  cluster                  Recipe_name  \
# 3671       529.64         1307.88        7  Keto Low Carb Curry recipes
#
#           Cuisine_type Diet_type
# 3671  south east asian      keto

# %%
recipe_recommendation()
# Out:
# Welcome to the TDEE Calculator!
# Please enter the following details:
# Weight (kg): 55
# Height (cm): 158
# Age (years): 36
# Gender (male/female): female
# Activity Level (sedentary/lightly active/moderately active/very active/extra active): very active
# What is your Goal: (Loss Weight/Maintain Weight/Gain Weight: loss weight
# Total Calories per meal based on your Goal is: 630.38 calories per meal.
#
# Macronutrient Distribution:
# Invalid activity level. Please choose from the provided options.
# /Users/brunasantos/anaconda3/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
#       Protein(g)  Protein Calorie  Carbs(g)  Carbs Calorie  Fat(g)  \
# 5164        40.3            161.2     66.18         264.72  121.73
#
#       Fat Calorie  Total Calories  cluster  \
# 5164       486.92          912.84        7
#
#                               Recipe_name Cuisine_type      Diet_type
# 5164  Cook the Book: Fried Halloumi Salad        asian  mediterranean
